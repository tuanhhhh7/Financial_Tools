# %% [markdown]
# ![vgu_campus.png](..\images\fscampus_small2.png)
#
# ***Finance I (OFIN)-SS2025***
#
# **Dr. Omer Cayirli**
#
# Lecturer in Empirical Finance
#
# omer.cayirli@vgu.edu.vn
#
# ---

# %% [markdown]
# ## Lecture 02
# ---

# %% [markdown]
# ### Outline
# * Time, Money, and Interest Rates
#   * The Time Value of Money
#   * Interest Rates
# ---

# %%
# %pip install -r ..\requirements.txt
# %pip install --upgrade notebook
# %pip install --upgrade jupyterlab
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\asus\appdata\roaming\python\python312\site-packages (from -r ..\requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: scipy in c:\users\asus\appdata\roaming\python\python312\site-packages (from -r ..\requirements.txt (line 2)) (1.15.1)
# Requirement already satisfied: networkx in c:\users\asus\appdata\roaming\python\python312\site-packages (from -r ..\requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from -r ..\requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: ipywidgets in c:\users\asus\appdata\roaming\python\python312\site-packages (from -r ..\requirements.txt (line 5)) (8.1.5)
# Requirement already satisfied: ipympl in c:\users\asus\appdata\roaming\python\python312\site-packages (from -r ..\requirements.txt (line 6)) (0.9.7)
# Requirement already satisfied: matplotlib-venn in c:\users\asus\appdata\roaming\python\python312\site-packages (from -r ..\requirements.txt (line 7)) (1.1.2)
# Requirement already satisfied: jupyterlab_widgets in c:\users\asus\appdata\roaming\python\python312\site-packages (from -r ..\requirements.txt (line 8)) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from matplotlib->-r ..\requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib->-r ..\requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib->-r ..\requirements.txt (line 1)) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib->-r ..\requirements.txt (line 1)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from matplotlib->-r ..\requirements.txt (line 1)) (24.1)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from matplotlib->-r ..\requirements.txt (line 1)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib->-r ..\requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from matplotlib->-r ..\requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: comm>=0.1.3 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipywidgets->-r ..\requirements.txt (line 5)) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipywidgets->-r ..\requirements.txt (line 5)) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipywidgets->-r ..\requirements.txt (line 5)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\asus\appdata\roaming\python\python312\site-packages (from ipywidgets->-r ..\requirements.txt (line 5)) (4.0.13)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (2.15.1)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r ..\requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (0.2.5)
# Requirement already satisfied: executing in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ..\requirements.txt (line 5)) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: notebook in c:\users\asus\appdata\roaming\python\python312\site-packages (7.3.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from notebook) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.6 in c:\users\asus\appdata\roaming\python\python312\site-packages (from notebook) (4.3.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from notebook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from notebook) (6.4.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.6.2)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.14)
# Requirement already satisfied: pyzmq>=24 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook) (2.2.0)
# Requirement already satisfied: setuptools>=40.8.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab<4.4,>=4.3.6->notebook) (75.1.0)
# Requirement already satisfied: babel>=2.10 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook) (2024.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (8.27.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (1.6.0)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.2.0)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.2.3)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (3.0.43)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (0.4.6)
# Requirement already satisfied: fqdn in c:\users\asus\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\asus\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\asus\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\asus\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (24.11.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (0.8.4)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (0.2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: executing in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (0.2.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\asus\appdata\roaming\python\python312\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.9.0.20241206)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyterlab in c:\users\asus\appdata\roaming\python\python312\site-packages (4.3.6)
# Requirement already satisfied: async-lru>=1.0.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (3.1.4)
# Requirement already satisfied: jupyter-core in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (0.2.3)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (24.1)
# Requirement already satisfied: setuptools>=40.8.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (75.1.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (6.4.2)
# Requirement already satisfied: traitlets in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from httpx>=0.25.0->jupyterlab) (4.6.2)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from httpx>=0.25.0->jupyterlab) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.0.2)
# Requirement already satisfied: idna in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from httpx>=0.25.0->jupyterlab) (3.7)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (25.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jinja2>=3.0.3->jupyterlab) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-core->jupyterlab) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-core->jupyterlab) (305.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.32.3)
# Requirement already satisfied: argon2-cffi-bindings in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->jupyterlab) (2024.1)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.15.1)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.2.0)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.2.3)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.4)
# Requirement already satisfied: fqdn in c:\users\asus\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\asus\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\asus\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\asus\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (24.11.1)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.5)
# Requirement already satisfied: executing in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\envs\anaconda-toolbox\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\asus\appdata\roaming\python\python312\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.9.0.20241206)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---

# %% [markdown]
# ### The timeline
# * Suppose you must pay tuition of $10,000 per year for the next two years.
# * Your tuition payments must be made in equal installments at the start of each semester.
# * What is the timeline of your tuition payments?
#
# **The Three Rules of Time Travel**
# * It is only possible to compare or combine values at the same point in time.
# * To move a cash flow forward in time, you must compound it.
# * To move a cash flow back in time, we must discount it.
#
# <center>
# <img src="../figures/timetravel_01.png" width="720"/>
# </center>
#
# ---

# %% [markdown]
# ### The timeline
# <center>
# <img src="../figures/timeline_01.png" width="640"/>
# </center>
# <center>
# <img src="../figures/timeline_02.png" width="640"/>
# </center>
#
# ---

# %% [markdown]
# ### The Time Value of Money
# * Suppose you plan to save $\$1000$ today, and $\$1000$ at the end of each of the next two years.
# * If you earn a fixed 10% interest rate on our savings, howcmuch will you have three years from today?
# <center>
# <img src="../figures/timetravel_02.png" width="720"/>
# </center>
# <center>
# <img src="../figures/timetravel_03.png" width="720"/>
# </center>
#
# ---

# %% [markdown]
# ### The Time Value of Money
#
# * $1,000 is deposited into a deposit account that pays 12% annual interest.
#
#   * Value after 1 year? Value after 2 years? Value after 3 years?
#
#     $$FV_1 = 1,000.00 \times (1 + 0.12) = 1,000.00 \times 1.12 = \$1,120.00$$
#
#     $$FV_2 = 1,120.00 \times (1 + 0.12) = 1,120.00 \times 1.12 = \$1,254.40$$
#
#     $$FV_3 = 1,254.40 \times (1 + 0.12) = 1,254.40 \times 1.12 = \$1,404.93$$
#
# |          | Year 1   | Year 2   | Year 3   | Total    |
# |----------|----------:|----------:|----------:|----------:|
# | Principal| \$1,000.00| \$1,000.00| \$1,000.00|          |
# | Interest | \$120.00  | \$120.00  | \$120.00  | \$360.00  |
# | Compound | \$120.00  | \$14.40   | \$14.40   | \$28.80   |
# | Extra    |          | \$14.40   | \$1.73    | \$1.73    |
# | **Total**|          |          |          | **\$404.93** |
#
# * **Total Interest (Compounded):** $\qquad \boxed{\$404.93}$
# * **Simple Interest:** $\qquad \qquad  \qquad \qquad 1,000.00 \times (0.12 \times 3) = \boxed{\$360.00}$
# * **Power of Compounding:** $\qquad \qquad \boxed{\$44.93}$
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import base64
import io
from IPython.display import display, HTML, clear_output
import ipywidgets as widgets
from IPython.display import Javascript

# Define the function to calculate simple interest FV
def simple_interest_fv(PV, r, t):
    return PV * (1 + r * t)

# Define the function to calculate compound interest FV
def compound_interest_fv(PV, r, t, m):
    return PV * (1 + r / m) ** (m * t)

# Function to generate and display the output
def generate_output(PV, t, r, m1, m2, output_widget):
    with output_widget:
        try:
            # Clear the output area for the plots and tables
            clear_output(wait=True)

            # Time periods for plotting
            time_periods = np.arange(1, t + 1)

            # Calculate FV for investment (constant)
            investment = np.full_like(time_periods, PV, dtype=float)

            # Calculate FV for simple and compound interest
            simple_fv = simple_interest_fv(PV, r, time_periods)
            compound_fv_m1 = compound_interest_fv(PV, r, time_periods, m1)
            compound_fv_m2 = compound_interest_fv(PV, r, time_periods, m2)

            # Final FV values for the tables (at t)
            final_compound_fv_m1 = compound_interest_fv(PV, r, t, m1)
            final_compound_fv_m2 = compound_interest_fv(PV, r, t, m2)

            # Create a single figure with two subplots side by side
            fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

            # Plot 1: m=m1
            ax1.fill_between(time_periods, investment, simple_fv, color='yellow', label='Simple', alpha=0.7)
            ax1.fill_between(time_periods, simple_fv, compound_fv_m1, color='gray', label='Compound', alpha=0.7)
            ax1.fill_between(time_periods, 0, investment, color='blue', label='Investment', alpha=0.7)
            ax1.set_title(f"(t={t}, m={m1}, r={int(r*100)}%)")
            ax1.set_xlabel("t")
            ax1.set_ylabel("FV ($)")
            ax1.legend(loc="upper left")
            ax1.grid(True)

            # Plot 2: m=m2
            ax2.fill_between(time_periods, investment, simple_fv, color='yellow', label='Simple', alpha=0.7)
            ax2.fill_between(time_periods, simple_fv, compound_fv_m2, color='gray', label='Compound', alpha=0.7)
            ax2.fill_between(time_periods, 0, investment, color='blue', label='Investment', alpha=0.7)
            ax2.set_title(f"(t={t}, m={m2}, r={int(r*100)}%)")
            ax2.set_xlabel("t")
            ax2.legend(loc="upper left")
            ax2.grid(True)

            # Adjust layout to prevent overlap
            plt.tight_layout()

            # Save the figure to a buffer and close it
            buf = io.BytesIO()
            plt.savefig(buf, format='png', bbox_inches='tight')
            buf.seek(0)
            image_base64 = base64.b64encode(buf.getvalue()).decode('utf-8')
            plt.close(fig)
            buf.close()

            # Create image HTML
            image_html = f'<img src="data:image/png;base64,{image_base64}" style="width: 90%;"/>'

            # Create summary tables
            table_data_m1 = {
                "PV": [f"{PV:.2f}"],
                "t": [t],
                "m": [m1],
                "r": [f"{int(r*100)}%"],
                "FV": [f"{final_compound_fv_m1:.2f}"]
            }
            table_data_m2 = {
                "PV": [f"{PV:.2f}"],
                "t": [t],
                "m": [m2],
                "r": [f"{int(r*100)}%"],
                "FV": [f"{final_compound_fv_m2:.2f}"]
            }

            df_m1 = pd.DataFrame(table_data_m1)
            df_m2 = pd.DataFrame(table_data_m2)

            table_html_m1 = df_m1.to_html(index=False, float_format=lambda x: f"{x:.2f}")
            table_html_m2 = df_m2.to_html(index=False, float_format=lambda x: f"{x:.2f}")

            # Combine image and tables in HTML
            html_content = f"""
            <div style="display: flex; justify-content: space-between; align-items: flex-start; width: 100%;">
                <div style="flex: 1; text-align: center;">
                    <div>{image_html}</div>
                    <div style="display: flex; justify-content: space-around;">
                        <div style="flex: 1; margin-right: 10px;">{table_html_m1}</div>
                        <div style="flex: 1;">{table_html_m2}</div>
                    </div>
                </div>
            </div>
            """

            # Display new content in the output widget
            display(HTML(html_content))

        except Exception as e:
            clear_output(wait=True)
            display(HTML(f"<p style='color: red;'>Error: {str(e)}</p>"))

# Create interactive widgets
PV_widget = widgets.FloatText(value=1000, description='PV ($):', step=100)
t_widget = widgets.IntText(value=25, description='t (years):', min=1, max=50)
r_widget = widgets.FloatText(value=10, description='r (%):', step=0.1)
m1_widget = widgets.IntText(value=1, description='m1:', min=1, max=12)
m2_widget = widgets.IntText(value=2, description='m2:', min=1, max=12)

# Create regenerate button
button = widgets.Button(description="Regenerate")

# Create an output widget for the plots and tables
output_widget = widgets.Output()

# Define button click event
def on_button_clicked(b):
    PV = PV_widget.value
    t = t_widget.value
    r = r_widget.value / 100  # Convert percentage to decimal
    m1 = m1_widget.value
    m2 = m2_widget.value
    generate_output(PV, t, r, m1, m2, output_widget)

button.on_click(on_button_clicked)

# Organize widgets in a box
widget_box = widgets.VBox([
    PV_widget,
    t_widget,
    r_widget,
    m1_widget,
    m2_widget,
    button
])

# Display the widgets and output separately
display(widget_box)
display(output_widget)

# Initial generation
generate_output(1000, 25, 0.10, 1, 2, output_widget)
# Out:
# VBox(children=(FloatText(value=1000.0, description='PV ($):', step=100.0), IntText(value=25, description='t (y…
# Output()

# %% [markdown]
# ---

# %% [markdown]
# ### The Time Value of Money
#
# * The future value of the $1,000 deposit in an account paying 10% interest annually at the end of 10 years:
#
#     $FV = PV (1 + i)^n \qquad FV = 1,000 (1 + 0.10)^{10} \qquad FV = \$2,593.74$
#
# * What is the annual return on this deposit?
#
#     The total return over 10 years:
#     $$
#     \frac{2,593.74 - 1,000}{1,000} = 1.59374
#     $$
#     Average return per year:
#     $$
#     \frac{1.59374}{10} = 0.159374 \, \text{or} \, 15.94\%
#     $$
#
#     The exact annual return (geometric mean):
#     $$
#     \sqrt[10]{\frac{2,593.74}{1,000}} - 1 = \sqrt[10]{2.59374} - 1 = 0.10 \, \text{or} \, 10.00\%
#     $$
# ---

# %% [markdown]
# ### The Time Value of Money
#
# * You invest $5,000 today in an opportunity that will double your money in 5 years. What is the annual growth rate on your investment?
#
# $$
# FV = PV (1 + i)^n
# $$
#
# $$
# 10,000 = 5,000 (1 + i)^5
# $$
#
# $$
# \sqrt[5]{\frac{10,000}{5,000}} - 1 = 14.87\%
# $$
#
# * You invest $5,000 today in an opportunity that pays interest every six months and will double your money in 5 years. What is the promised annual interest rate on this deposit?
# ---

# %% [markdown]
# ### Example 2.1
# The investment doubles in 5 years, so:
# $$
# FV = PV \times (1 + r)^n
# $$
# where:
# - $FV = 2 \times PV$ (future value is twice the present value),
# - $PV = 5,000$ (initial investment),
# - $r$ is the interest rate per period,
# - $n = 10$ (since there are 10 six-month periods in 5 years).
#
# The promised annual interest rate can be calculated as:
# $$
# \text{Annual Rate} = (1 + r_{\text{semiannual}})^2 - 1
# $$
# where $r_{\text{semiannual}}$ is the interest rate per six-month period.
#
# ---

# %% [markdown]
# ### Valuing a stream of cash flows
#    * When the payments are made (beginning vs. end of the period) is important.
#    * Standard formulas apply to regular payments made at regular intervals.
#    * Future value vs. present value formulas.
#
# **Future value of a fixed amount paid at the end of each period**
# $$
# FV = CF \left[ \frac{(1+i)^n - 1}{i} \right]
# $$
#
# **Future value of a fixed amount paid at the beginning of each period**
# $$
# FV = CF \left[ \frac{(1+i)^n - 1}{i} \right] * (1 + i)
# $$
#
# **Present value of a fixed amount paid at the end of each period**
# $$
# PV = CF \left[ \frac{1 - \frac{1}{(1+i)^n}}{i} \right]
# $$
#
# **Present value of a fixed amount paid at the beginning of each period**
#
# $\qquad \qquad \qquad \qquad \qquad \qquad \qquad PV = CF [\frac{1 - \frac{1}{(1+i)^{n-1}}}{i}] + \text{CF} \qquad \text{or} \qquad PV = CF [ \frac{1 - \frac{1}{(1 + i)^n}}{i}] \times (1 + i)$
#
# ---

# %% [markdown]
# ### The Time Value of Money
#
# * Arturu Corp offers a payment plan on a new car of $5,000 a year, paid at the end of each of the next five years, with no cash down. If the current interest rate is 7%, what is the car really costing you?
#
# $PV = CF \left[ \frac{1-\frac{1}{(1+i)^n}}{i} \right] \quad \rightarrow \quad PV = 5000 \left[ \frac{1-\frac{1}{(1 + 0.07)^5}}{0.07} \right]
# \quad \rightarrow \quad PV = 5000 \left[ \frac{0.287014}{0.07} \right] \quad \rightarrow \quad PV = 5000 * 4.1002 \, \rightarrow \,\ PV = \$20,501$
# <center>
# <img src="../figures/loancost.png" width="900"/>
# </center>
#
# ---

# %% [markdown]
# ### The Time Value of Money
# * Suppose a business takes out a $\$25,000$, five-year loan at 8 percent. The loan agreement calls for the borrower to pay the interest on the loan balance each year and to reduce the loan balance each year by $5,000.
#
# **Amortization Table**
# | Year   | Beginning Balance | Interest Paid | Principal Paid | Total Payment | Ending Balance |
# |:--------:|-------------------:|---------------:|----------------:|---------------:|----------------:|
# | 1      | \$25,000          | \$2,000        | \$5,000         | \$7,000        | \$20,000        |
# | 2      | \$20,000          | \$1,600        | \$5,000         | \$6,400        | \$15,000        |
# | 3      | \$15,000          |\$1,200        | \$5,000         | \$5,800        | \$10,000        |
# | 4      | \$10,000          | \$800          | \$5,000         | \$5,200        | \$5,000         |
# | 5      | \$5,000           | \$400          | \$5,000         | \$4,600        | \$0             |
# | Totals |                  | \$4,000        | \$25,000        | \$29,000       |                |
#
# 1. **Beginning Balance**: The loan balance at the start of the year.
# 2. **Total Payment**: The sum of the interest paid and the principal paid for the year. $\; \text{Total Payment} = \text{Interest Paid} + \text{Principal Paid}$
# 3. **Interest Paid**: $\; \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad \quad \; \; \,\text{Interest Paid} = \text{Beginning Balance} \times \text{Interest Rate}$
# 4. **Principal Paid**: $\; \; \; \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad \quad \; \; \, \text{\quad Fixed at \$5,000 per year.}$
# 5. **Ending Balance**: The remaining loan balance after the payment is made. $\qquad \, \text{\quad Ending Balance} = \text{Beginning Balance} - \text{Principal Paid}$
# ---

# %% [markdown]
# ### The Time Value of Money
# * Now assume that the borrower wants to make a fixed payment every period. What is the monthly payment amount that amortizes this lone fully at the end of 5th year?
#
# $PV = CF \times \frac{1 - \frac{1}{(1 + i)^n}}{i} \qquad \rightarrow \qquad 25000 = CF \times \frac{1 - \frac{1}{(1 + 0.08)^5}}{0.08} \qquad \rightarrow \qquad 25000 = CF \times \frac{1 - 0.680583}{0.08}$
#
# $25000 = CF \times 3.992712 \qquad \rightarrow \qquad CF = \frac{25000}{3.992712} \qquad \rightarrow \qquad CF = \$6,261.09$
#
# **Amortization Table for Fixed Payments of $6,261.09**
#
# | Year   | Beginning Balance | Interest Paid | Principal Paid | Total Payment | Ending Balance |
# |--------:|-------------------:|---------------:|----------------:|---------------:|----------------:|
# | 1      | \$25,000.00          | \$2,000.00        | \$4,261.09      | \$6,261.09     | \$20,738.91     |
# | 2      | \$20,738.91       | \$1,659.11     | \$4,601.98      | \$6,261.09     | \$16,136.93     |
# | 3      | \$16,136.93       | \$1,290.95     | \$4,970.14      | \$6,261.09     | \$11,166.79     |
# | 4      | \$11,166.79       | \$893.34       | \$5,367.75      | \$6,261.09     | \$5,799.04      |
# | 5      | \$5,799.04        | \$463.92       | \$5,797.17      | \$6,261.09     | \$0.00             |
# | Totals |                  | \$6,307.32     | \$25,000.00     | \$31,307.32    |                |
#
# ---

# %% [markdown]
# ### Exercise 2.1
#
# * Suppose that you take out a six-year loan of $\$10,000$.
#     * The bank requires you to repay the loan evenly over the six years.
#     * If the interest rate is 10\% a year, what should the annual payments be?
# * Now, suppose that you decide to make a $\$2,500$ baloon payment at the end of 3rd year.
#     * What should the annual payments be?
# ---

# %% [markdown]
# ### The Time Value of Money: Perpetuities
#
# * When a constant cash flow will occur at regular intervals forever it is called a perpetuity.
#
# * The value of a perpetuity is simply the cash flow divided by the interest rate.
# $$
# PV (C \ in \ Perpetuity) = \frac{C}{i}
# $$
#
# **Example 2.2**
#   * You are planning to establish a scholarship fund for underrepresented students in computer science at your university. The fund should provide $75,000 per year to support scholarships, research grants, and conference travel expenses. If the fund is expected to generate an annual return of 5%, how much money do you need to donate initially to sustain this yearly expenditure indefinitely?
#
# $$PV = \frac{C}{r}$$
# where:
# - $ PV $: Present Value (initial donation needed)
# - $ C $: Annual cash flow ($75,000)
# - $ r $: Annual rate of return (5% or 0.05)
#
# $\qquad PV = \frac{75,000}{0.05} \qquad \rightarrow \qquad PV = 1,500,000 \qquad \rightarrow \qquad \text{The initial donation required is \$1,500,000}$
#
# ---

# %%
# Annual cash flow required for the scholarship fund
C = 75000  

# Annual rate of return (as a decimal)
r = 0.05  

# Calculate the present value using the perpetuity formula
PV = C / r

print("The initial donation required is: ${:,.0f}".format(PV))
# Out:
# The initial donation required is: $1,500,000

# %% [markdown]
# ---

# %% [markdown]
# ### The Time Value of Money: Growing Perpetuity
# * Assume you expect the amount of your perpetual payment to increase at a constant rate, $g$. Then,
# $$PV (C \ \text{in} \ \text{Perpetuity}) = \frac{C}{i - g}$$
#
# * In the previous example, the university has asked you to increase the donation to account for the effect of inflation, which is expected to be
# 3% per year. How much more will you need to donate to satisfy that request?
# $$PV (C \ \text{in} \ \text{Perpetuity}) = \frac{\$75,000}{0.05 - 0.03} = \$3,750,000$$
#
# ---

# %%
# Annual cash flow required for the scholarship fund
C = 75000  

# Nominal annual rate of return (as a decimal)
r = 0.05  

# Expected annual inflation (growth) rate (as a decimal)
g = 0.03  

# Calculate the present value required for a growing perpetuity
PV_growing = C / (r - g)

# Calculate the nominal (non-growing) perpetuity required
PV_nominal = C / r

# Calculate the additional donation needed to fund a growing perpetuity
additional_donation = PV_growing - PV_nominal

print("Present Value for a growing perpetuity: ${:,.0f}".format(PV_growing))
print("Nominal Present Value (without growth): ${:,.0f}".format(PV_nominal))
print("Additional donation needed: ${:,.0f}".format(additional_donation))
# Out:
# Present Value for a growing perpetuity: $3,750,000
# Nominal Present Value (without growth): $1,500,000
# Additional donation needed: $2,250,000

# %% [markdown]
# ---

# %% [markdown]
# ### The Time Value of Money: Growing Annuity
#
# * The present value of a growing annuity with the initial cash flow, $C$, growth rate, $g$, and interest rate, $i$, is defined as
# $$
# PV = \frac{C}{i - g} \times \left[ 1 - \left( \frac{1 + g}{1 + i} \right)^N \right]
# $$
#
# **Example**
# * You want to begin saving for your retirement. You plan to contribute $\$10,000$ to the account at the end of this year. You anticipate you will be able to increase your annual contributions by 4% each year for the next 40 years. If your expected annual return is 8%, how much do you expect to have in your retirement account when you retire in 40 years?
# $$
# PV = \frac{10,000}{0.08 - 0.04} \times \left[ 1 - \left( \frac{1 + 0.04}{1 + 0.08} \right)^{40} \right] = 250,000 \times 0.779 \approx \$194,750
# $$
#
# * What will the future value of your savings be when you retire?
# $$
# FV = PV \times (1 + i)^N = 194,750 \times (1 + 0.08)^{40} \approx \$4,230,850.56
# $$
# ---

# %%
# Parameters for the growing annuity
C = 10000    # Initial contribution at the end of the first year
r = 0.08     # Expected annual return (8%)
g = 0.04     # Annual growth rate of contributions (4%)
n = 40       # Number of years of contributions

# Calculate the future value of the growing annuity using the formula:
# FV = C * [ (1 + r)^n - (1 + g)^n ] / (r - g)
FV = C * ((1 + r)**n - (1 + g)**n) / (r - g)

print("Future Value of your retirement savings: ${:,.2f}".format(FV))
# Out:
# Future Value of your retirement savings: $4,230,875.22

# %% [markdown]
# ---

# %%
import ipywidgets as widgets
from ipywidgets import interact
import numpy as np
import matplotlib.pyplot as plt

def calculate_future_value(C, r, g, n):
    """
    Calculate the future value of retirement savings using a growing annuity and plot the savings growth over time.
    
    Parameters:
    C : float
        Initial contribution at the end of the first year.
    r : float
        Expected annual return (as a decimal).
    g : float
        Annual growth rate of contributions (as a decimal).
    n : int
        Number of years of contributions.
    """
    # Calculate the future value of the growing annuity
    FV = C * ((1 + r)**n - (1 + g)**n) / (r - g)
    
    # Calculate the savings growth over time
    years = np.arange(n + 1)  # Time points from 0 to n
    future_values = np.zeros(n + 1)  # Array to store future values at each year
    
    for t in range(1, n + 1):
        future_values[t] = C * ((1 + r)**t - (1 + g)**t) / (r - g)
    
    # Print the future value at retirement
    print("Future Value of your retirement savings: ${:,.2f}".format(FV))
    
    # Plot the savings growth over time
    plt.figure(figsize=(8, 5))
    plt.plot(years, future_values, marker='o', linestyle='-', color='b', label="Future Value Over Time")
    plt.xlabel("Years")
    plt.ylabel("Future Value ($)")
    plt.title("Growth of Retirement Savings Over Time")
    plt.grid(True)
    plt.legend()
    plt.show()

# Create interactive widgets for input parameters
interact(
    calculate_future_value,
    C=widgets.FloatText(value=10000, description='Initial Contribution ($):'),
    r=widgets.FloatSlider(value=0.08, min=0.0, max=0.2, step=0.01, description='Annual Return (r):'),
    g=widgets.FloatSlider(value=0.04, min=0.0, max=0.2, step=0.01, description='Growth Rate (g):'),
    n=widgets.IntSlider(value=40, min=1, max=100, step=1, description='Years (n):')
)
# Out:
# interactive(children=(FloatText(value=10000.0, description='Initial Contribution ($):'), FloatSlider(value=0.0…
# <function __main__.calculate_future_value(C, r, g, n)>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 2.2
#
# In September 2019, a Californian man won a record $\$680$ million lottery prize, to be paid out over 30 annual installments.
#
# The first payment was $\$10$ million, and each subsequent payment increased by 5% per year, so that the final payment is approximately $\$41.16$ million.
#
# If the annual interest rate is 3%, what is the present value of this $\$680$ million prize?
#
#
# ---

# %% [markdown]
# ### Exercise 2.3
#
# A second-year MBA student has just been offered a job at $95,000 a year.
#
# She anticipates her salary to increase by $5\%$ a year until her retirement in 40 years.
#
# Given an interest rate of $10\%$, what is the present value of her lifetime salary?
#
# ---

# %% [markdown]
# ### Exercise 2.4
#
# Olivia and Mark are preparing for their son Ethan's future education expenses. They project that when Ethan enters college in 16 years, the cost will be \$35,000 per year for four years. The annual interest rate for the savings period is expected to be 10%.
#
#   * How much money must Olivia and Mark deposit each year so that Ethan's four years of college expenses will be fully covered?
#
#   * Alternatively, if they decide to increase the deposit amount by 5% each year, what should their first deposit be?
#
# ---

# %% [markdown]
# ### Interest Rates
#
# #### Annual Percentage Rate (APR)
# * The amount of simple interest earned/paid in one year (the amount of interest earned/paid without the effect of compounding.)
#   * Does not reflect the true amount you will earn/pay over one year.
#   * Can't use the APR as a discount rate.
#   * APR becomes meaningful only if the compounding interval is given.
#
# #### Effective Annual Rate (EAR)
#   * The actual amount of interest that will be earned/paid at the end of one year.
# $$
# (1 + EAR) = (1 + \frac{APR}{k})^k
# $$
# **Example 2.3**
# * If the annual percentage rate (APR) is 8 percent, and compounded quarterly, what is the effective annual rate?
# $$
# (1 + EAR) = (1 + \frac{0.08}{4})^4
# $$
# $$
# (1 + EAR) = (1 + \frac{0.08}{4})^4 \quad EAR = 8.24\%
# $$
#
# ---

# %% [markdown]
# ### Example 2.4
# Check Express offers you the following deal: you can write a check for $\$110$ that is dated 14 days in the future, and in return, they give you $\$100$ in cash today. Determine the Annual Percentage Rate (APR) and the Effective Annual Rate (EAR) for this arrangement.
#
# $FV = PV (1 + i)^n \qquad \rightarrow \qquad 110 = 100 (1 + i)^1 \qquad \rightarrow \qquad i=10%$
#
# $APR = 10\% * (\frac{365}{14}) = 260.71\%$
#
# $EAR = (1 + \frac{APR}{k})^k - 1 \qquad \rightarrow \qquad EAR = (1 + \frac{260.71\%}{365/14})^{\frac{365}{14}}-1 \qquad \rightarrow \qquad EAR \approx 1,100\%$
#
# ---

# %% [markdown]
# ### Interest Rates: Continuous Compounding
#
# * There is no limit to how frequently interest could be paid.
# * Compounding every infinitesimal instant is called continuous compounding.
#
# $\qquad FV = PV\left[\left(1 + \frac{r}{k}\right)^k\right]^T \qquad \text{and} \qquad \lim_{k \to \infty} \left(1 + \frac{r}{k}\right)^k = e^r$
#
# $\qquad \lim_{k \to \infty} \left[\left(1 + \frac{r}{k}\right)^k\right]^T = \left(e^r\right)^T \qquad \rightarrow \qquad FV = PV\left[\left(1 + \frac{r}{k}\right)^k\right]^T= e^{rT}$
#
# <center>
# <img src="../figures/compounding_comp.png" width="900"/>
# </center>
#
# ---

# %% [markdown]
# ### Example 2.5
# * You will be paid $\$50,000$ at the end of five years. If the annual continuously compounded rate of interest is 7 percent, what is the present value of this payment?
# $$FV = PV * e^{rT}$$
# $$50,000 = PV * e^{0.07*5}$$
# $$50,000 = PV * 1.4191 \quad \rightarrow \qquad  PV = \$35,234.40$$
#
# ---

# %% [markdown]
# ### Exercise 2.5
# * You are quoted an interest rate of 9% on an investment of $15,000. What is the value of your investment after five years if interest is compounded:
#
#   * Annually?
#
#   * Monthly?
#
#   * Continuously?
#
# ---

# %% [markdown]
# ### Exercise 2.6
# * What is the present value of an annuity of $6,200 per year, with the first cash flow received four years from today and the last one received 28 years from today if the appropriate discount rate is 7 percent?
#
# ---

# %% [markdown]
# ### Exercise 2.7
# * What is the value today of a 20-year annuity that pays $1,200 a year? The annuity's first payment occurs seven years from today. The annual interest rate is 10 percent for the years 1 through 5, and 14 percent thereafter.
#
# ---

# %% [markdown]
# ### Exercise 2.8
# * You want to borrow $\$100,000$ from your local bank to buy a new vehicle. You can afford to make monthly payments of $\$2,100$, but no more. Assuming monthly compounding, what is the highest APR you can afford on a 60-month loan?
#
# ---

# %% [markdown]
# ### Exercise 2.9
# * You are planning to save for retirement over the next 30 years. You will invest $\$1,000$ per month in a diversified equity fund in real dollars and $\$300$ per month in a municipal bond fund in real dollars. The effective annual return of the equity fund is expected to be 10%, and the bond fund will earn 6%. When you retire, you will combine your money into an account with an effective return of 7%. The inflation rate over this period is expected to be 3%. How much can you withdraw each month from your account in real terms assuming a withdrawal period of 25 years? What is the nominal dollar amount of your last withdrawal?
#
# ---

# %% [markdown]
# ### What is next?
# * Problem Set 2
# * Next Lecture
#     * Investment Decision Rules
#         * Reading(s): CF-B&D: Ch. 7
# ---
